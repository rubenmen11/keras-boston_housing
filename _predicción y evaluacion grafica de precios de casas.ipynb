# %% [markdown]
# ![texto alternativo](https://drive.google.com/uc?id=1_ZoJOp39dxsRTVndJP1_7jdY7oGi8sSu)
#
# <h1><center>Redes Neuronales con Keras y Scikit</center></h1>
#
#
# <center><i>Creando nuestra primera red neuronal</i></center>

# %% [markdown]
# # <h1>Contenido</h1>
#
# <div class="alert alert-block alert-warning" style="margin-top: 20px">
#     <ol>
#         <li><a href="#problema">Contexto Analítico</a></li>
#         <li><a href="#arquitectura">Arquitectura propuesta</a></li>
#         <li><a href="#keras">Entrenamiento y Evaluación del Modelo</a></li>
#     </ol>
# </div>
# <br>
# <hr>
# Para encontrar mas contenido de datasetes en keras, nos metemos a keras.io/datasets

# %% [markdown]
# # <h1 id="problema">Contexto analítico</h1>
#
# Requerimos diseñar un modelo que permita determinar el precio medio de las viviendas en Boston, para ello contamos con un set de información disponible en Keras con características y precios de viviendas en diferentes ubicaciones de Boston de finales de 1970. (Mayor detalle disponible en http://lib.stat.cmu.edu/datasets/boston
#
# En total contamos con 506 muestras caracterizadas por 13 variables.

# %% [markdown]
#  Variables | Description
#  --- | ---
#  CRIM   |  per capita crime rate by town
#  ZN     |  proportion of residential land zoned for lots over 25,000 sq.ft.
#  INDUS  |  proportion of non-retail business acres per town
#  CHAS   |  Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#  NOX    |  nitric oxides concentration (parts per 10 million)
#  RM     |  average number of rooms per dwelling
#  AGE    |  proportion of owner-occupied units built prior to 1940
#  DIS    |  weighted distances to five Boston employment centres
#  RAD    |  index of accessibility to radial highways
#  TAX    |  full-value property-tax rate per \$10,000
#  PTRATIO|  pupil-teacher ratio by town
#  B      |  1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#  LSTAT  |  % lower status of the population
#  MEDV   |  Median value of owner-occupied homes in $1000's

# %%
# Estos 2 comandos los copiamos de la pagina de keras
from keras.datasets import boston_housing
(x_train, y_train), (x_test, y_test) = boston_housing.load_data(test_split=0.2,seed=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step

# %%
print("Tamaño set de entrenamiento:",x_train.shape)
print("Tamaño set de prueba:", x_test.shape)
# Out:
# Tamaño set de entrenamiento: (404, 13)
# Tamaño set de prueba: (102, 13)

# %%
print("Tamaño set de entrenamiento:",x_train.shape)
print("Tamaño set de prueba:",x_test.shape)
# Out:
# Tamaño set de entrenamiento: (404, 13)
# Tamaño set de prueba: (102, 13)

# %%
x_train[:1]
# Out:
# array([[5.4790e-02, 3.3000e+01, 2.1800e+00, 0.0000e+00, 4.7200e-01,
#         6.6160e+00, 5.8100e+01, 3.3700e+00, 7.0000e+00, 2.2200e+02,
#         1.8400e+01, 3.9336e+02, 8.9300e+00]])

# %% [markdown]
# # <h1 id="arquitectura">Arquitectura propuesta</h1>
#
# Para diseñar el modelo implementaremos un red tal y como se ilustra enseguida:
#
# ![Arquitectura1](https://drive.google.com/uc?id=1RndIWQ4yVr9AvWi6Zbn6QNRpAJf33VeV)
#
# La arquitectuea que usaremos es  una rede neuronal de 13 entrados, con 2 capas ocultas, la primera con 6 la segunda con 4 y una salida que es el precio

# %%
import numpy as np
#Sequencial es para poner capa a capa la red neuronal
from keras.models import Sequential
#Capapa dense es la que coneta capa a capa la red neuronal
from keras.layers import Dense, Activation

#Definición de la arquitectura
#Esta es la cracion de la capas
#La activacion ReLu sirve para que todos los valores negativos se hagan 0
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='normal',activation='relu'))
model.add(Dense(6, kernel_initializer='normal',activation='relu'))
model.add(Dense(4, kernel_initializer='normal',activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))

# Compilación del modelo
#Despues compilamos el modelo y como es un modelo de regresion aplicamos el mean squared error
model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mean_absolute_percentage_error'])

# %%
#Aqui veos como esta compuesta la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 13)                182
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 84
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 28
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 299
# Trainable params: 299
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Aqui se grafica el modelo
from keras.utils import plot_model
plot_model(model, to_file='model.png',show_shapes=True)

# %% [markdown]
# # <h1 id="keras">Entrenamiento y Evaluación del modelo</h1>
#
# Ahora realizaremos diferentes entrenamientos de la red neuronal diseña y evaluaremos su desempeño.

# %%
#Entrena el modelo
#set de entrenamiento, valores numericos
x_val = x_train[300:,]
#Set de entrenamiento, etiquetas
y_val = y_train[300:,]
#Entrena el modelo
model.fit(x_train, y_train, batch_size=32, epochs=5,validation_data=(x_val,y_val))
#El resultado es mediocre
# Out:
# Epoch 1/5
# 13/13 [==============================] - 0s 12ms/step - loss: 588.1601 - mean_absolute_percentage_error: 99.6669 - val_loss: 531.9219 - val_mean_absolute_percentage_error: 99.2162
# Epoch 2/5
# 13/13 [==============================] - 0s 2ms/step - loss: 580.3037 - mean_absolute_percentage_error: 98.5855 - val_loss: 518.9069 - val_mean_absolute_percentage_error: 97.3169
# Epoch 3/5
# 13/13 [==============================] - 0s 2ms/step - loss: 557.8512 - mean_absolute_percentage_error: 95.6813 - val_loss: 484.0553 - val_mean_absolute_percentage_error: 92.0609
# Epoch 4/5
# 13/13 [==============================] - 0s 2ms/step - loss: 502.1243 - mean_absolute_percentage_error: 87.3777 - val_loss: 402.1315 - val_mean_absolute_percentage_error: 78.5675
# Epoch 5/5
# 13/13 [==============================] - 0s 2ms/step - loss: 383.6529 - mean_absolute_percentage_error: 69.9309 - val_loss: 255.5396 - val_mean_absolute_percentage_error: 55.2636

# %%
model.fit(x_train, y_train, batch_size=32, epochs=100,validation_data=(x_val,y_val))
#Aqui vemos que el porcentage de error disminuyo debido a que se cambiaron las epocas, desto quiere decir que entre mas iteraciones da, mejores resultados arroja

# %%
results = model.evaluate(x_test, y_test)

for i in range(len(model.metrics_names)):
  print(model.metrics_names[i]," : ", results[i])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 277.3588 - mean_absolute_percentage_error: 54.6682
# loss  :  277.3587951660156
# mean_absolute_percentage_error  :  54.66817092895508

# %%
model.fit(x_train, y_train, batch_size=32, epochs=100,validation_data=(x_val,y_val))
# Out:
# Epoch 1/100
# 13/13 [==============================] - 0s 5ms/step - loss: 220.4883 - mean_absolute_percentage_error: 51.2131 - val_loss: 141.8502 - val_mean_absolute_percentage_error: 49.0018
# Epoch 2/100
# 13/13 [==============================] - 0s 2ms/step - loss: 156.0938 - mean_absolute_percentage_error: 54.8874 - val_loss: 146.8670 - val_mean_absolute_percentage_error: 58.0667
# Epoch 3/100
# 13/13 [==============================] - 0s 3ms/step - loss: 144.9129 - mean_absolute_percentage_error: 52.9484 - val_loss: 128.0530 - val_mean_absolute_percentage_error: 49.4062
# Epoch 4/100
# 13/13 [==============================] - 0s 2ms/step - loss: 134.9925 - mean_absolute_percentage_error: 47.8744 - val_loss: 121.6780 - val_mean_absolute_percentage_error: 47.7660
# Epoch 5/100
# 13/13 [==============================] - 0s 2ms/step - loss: 128.3637 - mean_absolute_percentage_error: 46.8086 - val_loss: 116.3695 - val_mean_absolute_percentage_error: 46.8409
# Epoch 6/100
# 13/13 [==============================] - 0s 2ms/step - loss: 122.3328 - mean_absolute_percentage_error: 45.5814 - val_loss: 111.1099 - val_mean_absolute_percentage_error: 45.2849
# Epoch 7/100
# 13/13 [==============================] - 0s 2ms/step - loss: 116.8834 - mean_absolute_percentage_error: 43.6334 - val_loss: 105.9812 - val_mean_absolute_percentage_error: 43.5202
# Epoch 8/100
# 13/13 [==============================] - 0s 3ms/step - loss: 111.4054 - mean_absolute_percentage_error: 42.7018 - val_loss: 102.3245 - val_mean_absolute_percentage_error: 43.3416
# Epoch 9/100
# 13/13 [==============================] - 0s 3ms/step - loss: 106.9389 - mean_absolute_percentage_error: 42.2593 - val_loss: 97.6823 - val_mean_absolute_percentage_error: 41.8615
# Epoch 10/100
# 13/13 [==============================] - 0s 3ms/step - loss: 102.4234 - mean_absolute_percentage_error: 39.4118 - val_loss: 92.9219 - val_mean_absolute_percentage_error: 39.0206
# Epoch 11/100
# 13/13 [==============================] - 0s 3ms/step - loss: 97.5588 - mean_absolute_percentage_error: 38.8792 - val_loss: 91.1557 - val_mean_absolute_percentage_error: 41.1518
# Epoch 12/100
# 13/13 [==============================] - 0s 3ms/step - loss: 93.8921 - mean_absolute_percentage_error: 39.2836 - val_loss: 86.2071 - val_mean_absolute_percentage_error: 38.5015
# Epoch 13/100
# 13/13 [==============================] - 0s 2ms/step - loss: 91.2983 - mean_absolute_percentage_error: 35.3668 - val_loss: 82.6121 - val_mean_absolute_percentage_error: 36.4217
# Epoch 14/100
# 13/13 [==============================] - 0s 2ms/step - loss: 86.2282 - mean_absolute_percentage_error: 36.1742 - val_loss: 81.8507 - val_mean_absolute_percentage_error: 39.3769
# Epoch 15/100
# 13/13 [==============================] - 0s 2ms/step - loss: 83.8831 - mean_absolute_percentage_error: 35.6294 - val_loss: 77.3481 - val_mean_absolute_percentage_error: 36.4009
# Epoch 16/100
# 13/13 [==============================] - 0s 2ms/step - loss: 80.0760 - mean_absolute_percentage_error: 34.4971 - val_loss: 75.4218 - val_mean_absolute_percentage_error: 36.5854
# Epoch 17/100
# 13/13 [==============================] - 0s 2ms/step - loss: 77.6891 - mean_absolute_percentage_error: 33.4302 - val_loss: 73.1119 - val_mean_absolute_percentage_error: 35.7293
# Epoch 18/100
# 13/13 [==============================] - 0s 3ms/step - loss: 75.1873 - mean_absolute_percentage_error: 32.7221 - val_loss: 71.4568 - val_mean_absolute_percentage_error: 35.3329
# Epoch 19/100
# 13/13 [==============================] - 0s 2ms/step - loss: 73.4268 - mean_absolute_percentage_error: 31.7623 - val_loss: 70.0717 - val_mean_absolute_percentage_error: 34.7906
# Epoch 20/100
# 13/13 [==============================] - 0s 2ms/step - loss: 72.6988 - mean_absolute_percentage_error: 33.4964 - val_loss: 69.9249 - val_mean_absolute_percentage_error: 36.1862
# Epoch 21/100
# 13/13 [==============================] - 0s 3ms/step - loss: 71.2071 - mean_absolute_percentage_error: 31.4007 - val_loss: 68.3600 - val_mean_absolute_percentage_error: 34.5178
# Epoch 22/100
# 13/13 [==============================] - 0s 3ms/step - loss: 69.6603 - mean_absolute_percentage_error: 31.6324 - val_loss: 68.6059 - val_mean_absolute_percentage_error: 36.1162
# Epoch 23/100
# 13/13 [==============================] - 0s 3ms/step - loss: 69.1232 - mean_absolute_percentage_error: 32.2183 - val_loss: 67.3719 - val_mean_absolute_percentage_error: 34.8346
# Epoch 24/100
# 13/13 [==============================] - 0s 2ms/step - loss: 68.1221 - mean_absolute_percentage_error: 31.0814 - val_loss: 67.0712 - val_mean_absolute_percentage_error: 35.0709
# Epoch 25/100
# 13/13 [==============================] - 0s 3ms/step - loss: 67.5583 - mean_absolute_percentage_error: 30.8913 - val_loss: 66.5755 - val_mean_absolute_percentage_error: 34.7298
# Epoch 26/100
# 13/13 [==============================] - 0s 3ms/step - loss: 66.8902 - mean_absolute_percentage_error: 30.9370 - val_loss: 66.4353 - val_mean_absolute_percentage_error: 35.1273
# Epoch 27/100
# 13/13 [==============================] - 0s 3ms/step - loss: 66.4745 - mean_absolute_percentage_error: 31.2391 - val_loss: 65.9892 - val_mean_absolute_percentage_error: 34.9246
# Epoch 28/100
# 13/13 [==============================] - 0s 3ms/step - loss: 65.9748 - mean_absolute_percentage_error: 30.7981 - val_loss: 65.2067 - val_mean_absolute_percentage_error: 34.1120
# Epoch 29/100
# 13/13 [==============================] - 0s 3ms/step - loss: 65.8448 - mean_absolute_percentage_error: 30.5241 - val_loss: 64.8881 - val_mean_absolute_percentage_error: 34.2589
# Epoch 30/100
# 13/13 [==============================] - 0s 3ms/step - loss: 65.5979 - mean_absolute_percentage_error: 30.8269 - val_loss: 64.5105 - val_mean_absolute_percentage_error: 34.1401
# Epoch 31/100
# 13/13 [==============================] - 0s 2ms/step - loss: 64.8845 - mean_absolute_percentage_error: 30.2936 - val_loss: 64.0036 - val_mean_absolute_percentage_error: 33.8878
# Epoch 32/100
# 13/13 [==============================] - 0s 2ms/step - loss: 64.5760 - mean_absolute_percentage_error: 30.2369 - val_loss: 63.8462 - val_mean_absolute_percentage_error: 34.2918
# Epoch 33/100
# 13/13 [==============================] - 0s 3ms/step - loss: 63.9146 - mean_absolute_percentage_error: 29.6852 - val_loss: 63.1108 - val_mean_absolute_percentage_error: 33.6017
# Epoch 34/100
# 13/13 [==============================] - 0s 3ms/step - loss: 63.5493 - mean_absolute_percentage_error: 29.7867 - val_loss: 62.9630 - val_mean_absolute_percentage_error: 34.0474
# Epoch 35/100
# 13/13 [==============================] - 0s 2ms/step - loss: 63.2110 - mean_absolute_percentage_error: 29.2835 - val_loss: 62.2393 - val_mean_absolute_percentage_error: 33.4907
# Epoch 36/100
# 13/13 [==============================] - 0s 3ms/step - loss: 62.7717 - mean_absolute_percentage_error: 29.9081 - val_loss: 62.0486 - val_mean_absolute_percentage_error: 33.7287
# Epoch 37/100
# 13/13 [==============================] - 0s 3ms/step - loss: 62.3737 - mean_absolute_percentage_error: 29.4432 - val_loss: 61.0157 - val_mean_absolute_percentage_error: 32.1047
# Epoch 38/100
# 13/13 [==============================] - 0s 3ms/step - loss: 62.3147 - mean_absolute_percentage_error: 28.7296 - val_loss: 60.7439 - val_mean_absolute_percentage_error: 32.7850
# Epoch 39/100
# 13/13 [==============================] - 0s 3ms/step - loss: 61.7524 - mean_absolute_percentage_error: 27.9728 - val_loss: 60.5215 - val_mean_absolute_percentage_error: 32.9733
# Epoch 40/100
# 13/13 [==============================] - 0s 3ms/step - loss: 61.1989 - mean_absolute_percentage_error: 29.4686 - val_loss: 60.1276 - val_mean_absolute_percentage_error: 32.9086
# Epoch 41/100
# 13/13 [==============================] - 0s 3ms/step - loss: 60.8651 - mean_absolute_percentage_error: 27.8098 - val_loss: 59.4387 - val_mean_absolute_percentage_error: 32.2962
# Epoch 42/100
# 13/13 [==============================] - 0s 3ms/step - loss: 60.3307 - mean_absolute_percentage_error: 29.0059 - val_loss: 59.4752 - val_mean_absolute_percentage_error: 32.9186
# Epoch 43/100
# 13/13 [==============================] - 0s 3ms/step - loss: 59.8746 - mean_absolute_percentage_error: 27.9228 - val_loss: 58.5027 - val_mean_absolute_percentage_error: 31.8098
# Epoch 44/100
# 13/13 [==============================] - 0s 3ms/step - loss: 59.5215 - mean_absolute_percentage_error: 28.0335 - val_loss: 58.4959 - val_mean_absolute_percentage_error: 32.3701
# Epoch 45/100
# 13/13 [==============================] - 0s 3ms/step - loss: 59.1777 - mean_absolute_percentage_error: 27.9120 - val_loss: 57.8674 - val_mean_absolute_percentage_error: 31.8373
# Epoch 46/100
# 13/13 [==============================] - 0s 3ms/step - loss: 59.0982 - mean_absolute_percentage_error: 27.7175 - val_loss: 57.6912 - val_mean_absolute_percentage_error: 32.0173
# Epoch 47/100
# 13/13 [==============================] - 0s 3ms/step - loss: 58.8485 - mean_absolute_percentage_error: 28.2691 - val_loss: 57.1025 - val_mean_absolute_percentage_error: 31.4894
# Epoch 48/100
# 13/13 [==============================] - 0s 3ms/step - loss: 58.5916 - mean_absolute_percentage_error: 28.0042 - val_loss: 56.6087 - val_mean_absolute_percentage_error: 30.8331
# Epoch 49/100
# 13/13 [==============================] - 0s 3ms/step - loss: 58.1392 - mean_absolute_percentage_error: 26.5677 - val_loss: 56.4330 - val_mean_absolute_percentage_error: 31.3112
# Epoch 50/100
# 13/13 [==============================] - 0s 3ms/step - loss: 57.7199 - mean_absolute_percentage_error: 28.1238 - val_loss: 56.5847 - val_mean_absolute_percentage_error: 31.9088
# Epoch 51/100
# 13/13 [==============================] - 0s 2ms/step - loss: 57.9281 - mean_absolute_percentage_error: 27.1695 - val_loss: 56.0718 - val_mean_absolute_percentage_error: 31.6010
# Epoch 52/100
# 13/13 [==============================] - 0s 3ms/step - loss: 57.0829 - mean_absolute_percentage_error: 27.4052 - val_loss: 55.4691 - val_mean_absolute_percentage_error: 31.1779
# Epoch 53/100
# 13/13 [==============================] - 0s 3ms/step - loss: 56.9447 - mean_absolute_percentage_error: 26.5936 - val_loss: 55.0819 - val_mean_absolute_percentage_error: 31.0428
# Epoch 54/100
# 13/13 [==============================] - 0s 3ms/step - loss: 56.7380 - mean_absolute_percentage_error: 27.9395 - val_loss: 54.9418 - val_mean_absolute_percentage_error: 31.2319
# Epoch 55/100
# 13/13 [==============================] - 0s 2ms/step - loss: 56.2408 - mean_absolute_percentage_error: 26.1335 - val_loss: 54.0007 - val_mean_absolute_percentage_error: 29.7353
# Epoch 56/100
# 13/13 [==============================] - 0s 3ms/step - loss: 55.7412 - mean_absolute_percentage_error: 26.8737 - val_loss: 54.7741 - val_mean_absolute_percentage_error: 31.5170
# Epoch 57/100
# 13/13 [==============================] - 0s 3ms/step - loss: 55.6999 - mean_absolute_percentage_error: 26.6844 - val_loss: 53.3221 - val_mean_absolute_percentage_error: 29.8381
# Epoch 58/100
# 13/13 [==============================] - 0s 3ms/step - loss: 55.2836 - mean_absolute_percentage_error: 26.0798 - val_loss: 53.2588 - val_mean_absolute_percentage_error: 30.2892
# Epoch 59/100
# 13/13 [==============================] - 0s 3ms/step - loss: 54.9468 - mean_absolute_percentage_error: 27.3068 - val_loss: 53.2865 - val_mean_absolute_percentage_error: 30.7240
# Epoch 60/100
# 13/13 [==============================] - 0s 2ms/step - loss: 54.6770 - mean_absolute_percentage_error: 26.0242 - val_loss: 52.3741 - val_mean_absolute_percentage_error: 29.7998
# Epoch 61/100
# 13/13 [==============================] - 0s 3ms/step - loss: 54.2363 - mean_absolute_percentage_error: 25.9983 - val_loss: 52.6053 - val_mean_absolute_percentage_error: 30.5433
# Epoch 62/100
# 13/13 [==============================] - 0s 2ms/step - loss: 54.2591 - mean_absolute_percentage_error: 27.3462 - val_loss: 51.5048 - val_mean_absolute_percentage_error: 29.2453
# Epoch 63/100
# 13/13 [==============================] - 0s 3ms/step - loss: 53.5523 - mean_absolute_percentage_error: 25.3002 - val_loss: 51.4027 - val_mean_absolute_percentage_error: 29.6391
# Epoch 64/100
# 13/13 [==============================] - 0s 2ms/step - loss: 53.2651 - mean_absolute_percentage_error: 26.2731 - val_loss: 50.9332 - val_mean_absolute_percentage_error: 29.3931
# Epoch 65/100
# 13/13 [==============================] - 0s 3ms/step - loss: 52.6604 - mean_absolute_percentage_error: 25.6614 - val_loss: 50.4085 - val_mean_absolute_percentage_error: 28.9468
# Epoch 66/100
# 13/13 [==============================] - 0s 3ms/step - loss: 52.3567 - mean_absolute_percentage_error: 25.5670 - val_loss: 49.9094 - val_mean_absolute_percentage_error: 28.6786
# Epoch 67/100
# 13/13 [==============================] - 0s 3ms/step - loss: 52.0925 - mean_absolute_percentage_error: 25.0959 - val_loss: 49.5272 - val_mean_absolute_percentage_error: 28.5370
# Epoch 68/100
# 13/13 [==============================] - 0s 3ms/step - loss: 51.6632 - mean_absolute_percentage_error: 25.4746 - val_loss: 49.4394 - val_mean_absolute_percentage_error: 29.0007
# Epoch 69/100
# 13/13 [==============================] - 0s 3ms/step - loss: 51.7648 - mean_absolute_percentage_error: 24.6369 - val_loss: 49.2903 - val_mean_absolute_percentage_error: 29.2105
# Epoch 70/100
# 13/13 [==============================] - 0s 3ms/step - loss: 51.6877 - mean_absolute_percentage_error: 27.2719 - val_loss: 48.3559 - val_mean_absolute_percentage_error: 28.3747
# Epoch 71/100
# 13/13 [==============================] - 0s 3ms/step - loss: 51.0145 - mean_absolute_percentage_error: 23.4990 - val_loss: 47.6712 - val_mean_absolute_percentage_error: 27.2277
# Epoch 72/100
# 13/13 [==============================] - 0s 3ms/step - loss: 50.0528 - mean_absolute_percentage_error: 24.9394 - val_loss: 48.0835 - val_mean_absolute_percentage_error: 28.7844
# Epoch 73/100
# 13/13 [==============================] - 0s 3ms/step - loss: 49.6772 - mean_absolute_percentage_error: 25.2426 - val_loss: 47.0583 - val_mean_absolute_percentage_error: 27.6701
# Epoch 74/100
# 13/13 [==============================] - 0s 3ms/step - loss: 49.1370 - mean_absolute_percentage_error: 24.2023 - val_loss: 46.6833 - val_mean_absolute_percentage_error: 27.5888
# Epoch 75/100
# 13/13 [==============================] - 0s 3ms/step - loss: 48.8521 - mean_absolute_percentage_error: 23.8227 - val_loss: 46.3348 - val_mean_absolute_percentage_error: 27.5838
# Epoch 76/100
# 13/13 [==============================] - 0s 3ms/step - loss: 48.2925 - mean_absolute_percentage_error: 24.4518 - val_loss: 45.8862 - val_mean_absolute_percentage_error: 27.5237
# Epoch 77/100
# 13/13 [==============================] - 0s 3ms/step - loss: 48.1091 - mean_absolute_percentage_error: 23.9641 - val_loss: 45.8002 - val_mean_absolute_percentage_error: 27.9181
# Epoch 78/100
# 13/13 [==============================] - 0s 3ms/step - loss: 47.6224 - mean_absolute_percentage_error: 24.3836 - val_loss: 44.6163 - val_mean_absolute_percentage_error: 26.4871
# Epoch 79/100
# 13/13 [==============================] - 0s 3ms/step - loss: 47.5763 - mean_absolute_percentage_error: 22.5256 - val_loss: 44.8791 - val_mean_absolute_percentage_error: 27.6358
# Epoch 80/100
# 13/13 [==============================] - 0s 3ms/step - loss: 46.8441 - mean_absolute_percentage_error: 24.8125 - val_loss: 43.6814 - val_mean_absolute_percentage_error: 26.2569
# Epoch 81/100
# 13/13 [==============================] - 0s 3ms/step - loss: 46.3151 - mean_absolute_percentage_error: 22.8881 - val_loss: 43.3684 - val_mean_absolute_percentage_error: 26.4909
# Epoch 82/100
# 13/13 [==============================] - 0s 2ms/step - loss: 46.0460 - mean_absolute_percentage_error: 23.6632 - val_loss: 42.6171 - val_mean_absolute_percentage_error: 25.5386
# Epoch 83/100
# 13/13 [==============================] - 0s 3ms/step - loss: 44.9492 - mean_absolute_percentage_error: 22.7371 - val_loss: 42.9279 - val_mean_absolute_percentage_error: 26.9856
# Epoch 84/100
# 13/13 [==============================] - 0s 3ms/step - loss: 44.8727 - mean_absolute_percentage_error: 24.4338 - val_loss: 41.5551 - val_mean_absolute_percentage_error: 24.8972
# Epoch 85/100
# 13/13 [==============================] - 0s 3ms/step - loss: 44.9409 - mean_absolute_percentage_error: 21.8810 - val_loss: 41.2325 - val_mean_absolute_percentage_error: 25.5264
# Epoch 86/100
# 13/13 [==============================] - 0s 3ms/step - loss: 44.3235 - mean_absolute_percentage_error: 23.2442 - val_loss: 40.5021 - val_mean_absolute_percentage_error: 24.3241
# Epoch 87/100
# 13/13 [==============================] - 0s 2ms/step - loss: 43.4224 - mean_absolute_percentage_error: 22.3209 - val_loss: 40.2091 - val_mean_absolute_percentage_error: 25.2630
# Epoch 88/100
# 13/13 [==============================] - 0s 3ms/step - loss: 42.7505 - mean_absolute_percentage_error: 21.4985 - val_loss: 39.9096 - val_mean_absolute_percentage_error: 25.4794
# Epoch 89/100
# 13/13 [==============================] - 0s 3ms/step - loss: 42.1990 - mean_absolute_percentage_error: 23.2053 - val_loss: 39.3058 - val_mean_absolute_percentage_error: 25.0731
# Epoch 90/100
# 13/13 [==============================] - 0s 4ms/step - loss: 42.0493 - mean_absolute_percentage_error: 20.9552 - val_loss: 38.9750 - val_mean_absolute_percentage_error: 25.1304
# Epoch 91/100
# 13/13 [==============================] - 0s 3ms/step - loss: 41.5334 - mean_absolute_percentage_error: 22.8904 - val_loss: 37.7496 - val_mean_absolute_percentage_error: 23.3364
# Epoch 92/100
# 13/13 [==============================] - 0s 3ms/step - loss: 41.1088 - mean_absolute_percentage_error: 20.2233 - val_loss: 38.7404 - val_mean_absolute_percentage_error: 25.7252
# Epoch 93/100
# 13/13 [==============================] - 0s 3ms/step - loss: 41.3009 - mean_absolute_percentage_error: 23.0472 - val_loss: 36.8590 - val_mean_absolute_percentage_error: 23.0592
# Epoch 94/100
# 13/13 [==============================] - 0s 3ms/step - loss: 39.6434 - mean_absolute_percentage_error: 20.8876 - val_loss: 36.7367 - val_mean_absolute_percentage_error: 24.2488
# Epoch 95/100
# 13/13 [==============================] - 0s 3ms/step - loss: 39.1580 - mean_absolute_percentage_error: 22.3285 - val_loss: 35.8032 - val_mean_absolute_percentage_error: 22.7076
# Epoch 96/100
# 13/13 [==============================] - 0s 3ms/step - loss: 39.4705 - mean_absolute_percentage_error: 19.5608 - val_loss: 37.0141 - val_mean_absolute_percentage_error: 25.3775
# Epoch 97/100
# 13/13 [==============================] - 0s 3ms/step - loss: 39.2524 - mean_absolute_percentage_error: 22.0167 - val_loss: 34.7714 - val_mean_absolute_percentage_error: 22.3910
# Epoch 98/100
# 13/13 [==============================] - 0s 3ms/step - loss: 37.0927 - mean_absolute_percentage_error: 20.4595 - val_loss: 35.3141 - val_mean_absolute_percentage_error: 24.5615
# Epoch 99/100
# 13/13 [==============================] - 0s 3ms/step - loss: 37.2341 - mean_absolute_percentage_error: 20.9538 - val_loss: 33.7239 - val_mean_absolute_percentage_error: 22.2817
# Epoch 100/100
# 13/13 [==============================] - 0s 3ms/step - loss: 36.5994 - mean_absolute_percentage_error: 21.4379 - val_loss: 33.3415 - val_mean_absolute_percentage_error: 20.8366

# %%
results = model.evaluate(x_test, y_test)

for i in range(len(model.metrics_names)):
  print(model.metrics_names[i]," : ", results[i])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 36.1994 - mean_absolute_percentage_error: 16.9495
# loss  :  36.199432373046875
# mean_absolute_percentage_error  :  16.949491500854492

# %%
import matplotlib.pyplot as plt
#aqui hacemos un analisis de todo lo que hizo nuestra red neuronal
#aqui vemos entre mas iteraciones menos error hay

history = model.fit(x_train, y_train, batch_size=32, epochs=200,validation_data=(x_val,y_val), verbose=0)
# Plot training & validation accuracy values
plt.figure(figsize=(13,6))
plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model mean_absolute_percentage_error')
plt.ylabel('MAPE %')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
